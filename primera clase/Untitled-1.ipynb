# %%
t=5
T=20
print(f"La variable t es {t} ")
# Out:
# La variable t es 5

# %%
lista=[1,2,"el pepe",3.14]
print(lista[2])
print(lista[0])
# Out:
# el pepe
# 1

# %%
producto=1
contador=1
while contador <=5:
    producto*=contador
    contador+=1
print(f"el producto de los priero 5 numeros naturales es: {producto}")
# Out:
# el producto de los priero 5 numeros naturales es: 120

# %%
nombres=["Agustin","German","Camila"]
for i in nombres:
    print(i)
# Out:
# Agustin
# German
# Camila

# %%
calif=float(input("ingrese la nota del estudiante: "))
if calif >=4.0:
    print("el estudiante aprobo")
else:
    print("el estudiante debe estudiar mas,reprobado")
# Out:
# el estudiante aprobo

# %%
def potencia(b,n):
    r=b**n
    return r

resultado_potencia=potencia(3,5)
print(f"el resultado de la potencia es: {resultado_potencia}")
# Out:
# el resultado de la potencia es: 243
