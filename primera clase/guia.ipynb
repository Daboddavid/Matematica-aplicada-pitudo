# %% [markdown]
# # Guia laboratorio 0

# %%
# P1
verif=int(input("Ingrese un numero: "))
if verif<1:
    print("usted ingreso un numero negativo")
elif verif==0:
    print("usted ingreso 0")
elif verif>1:
    print("usted ingreso numero positivo")

# %%
# P2
par=int(input("ingrese un numero: "))
if par%2==0:
    print("el numero es par")
else:
    print("el numero es impar")

# %%
# P3
n=1
while n<=100:
    print(n)
    n+=1

# %%
# P4
while ing!="contraseña":
    ing=input("ingrese la contraseña: ").lower()
    if ing=="contraseña":
        print("contraseña correcta")
    else:
        print("contraseña incorrecta")

# %%
# P5
pap=int(input("ingrese un numero: "))
for i in range(1,13):
    result=pap*i
    print(f"{pap} x {i} = {result}")

# %%
# P6
def apyr(a,b):
    re=a*b
    return re
ap=int(input("ingrese un numero: "))
bp=int(input("ingrese otro numero: "))

resu=apyr(ap,bp)
print(f"la multiplicacion de ambos numeros es {resu}")

# %%
# P7
def convertir_grados_farenheit():
    cel=int(input("ingrese los grados celsius enteros: "))
    F=9/5*cel+32
    return F
convertir_grados_farenheit()
